# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a + b
#
# NameError: name 'a' is not defined

# %%
a = 10

# %%
b = 20

# %%
a + b
# Out:
# 30

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'a + b', 'a + b', 'a = 10', 'b = 20', 'a + b', 'print(globlas())', 'print(globals())'], '_oh': {5: 30}, '_dh': [WindowsPath('c:/fintech4/03python')], 'In': ['', 'a + b', 'a + b', 'a = 10', 'b = 20', 'a + b', 'print(globlas())', 'print(globals())'], 'Out': {5: 30}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001864804D630>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001864804E0E0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001864804E0E0>, 'open': <function open at 0x00000186469D3250>, '_': 30, '__': '', '___': '', '_i': 'print(globlas())', '_ii': 'a + b', '_iii': 'b = 20', '_i1': 'a + b', '_i2': 'a + b', '_i3'
# ...

# %% [markdown]
# # 테스트셀
