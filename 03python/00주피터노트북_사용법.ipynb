# %% [markdown]
# # 주피터 노트북 사용법 \<h1>
# * 하위목록1 \<ul>\<li>
#   * 하위목록2
#     * 하위목록3
# ## 주피터 노트북 사용법 \<h2>
# ### 주피터 노트북 사용법 \<h3>
# #### 주피터 노트북 사용법 \<h4>
# ##### 주피터 노트북 사용법 \<h5>
# ###### 주피터 노트북 사용법 \<h6>

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a + b
#
# NameError: name 'a' is not defined

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a + b
#
# NameError: name 'a' is not defined

# %%
b = 20

# %%
a = 10

# %%
print(globals())

# %% [markdown]
# # jupyter notbook 마크다운 문법

# %% [markdown]
# ## 제목
# * 제목은 \#의 개수에 따라 제목 크기가 달라진다.

# %% [markdown]
# # 제목1
# ## 제목 2
# ### 제목 3
# #### 제목 4

# %% [markdown]
# ## 문단 & 줄바꿈

# %% [markdown]
# ### 문단
# * 한 줄의 비우면 새로운 문단이 된다.

# %% [markdown]
# 이것은 첫 번째 문단이다.
# 이것은 두 번째 문단이다.

# %% [markdown]
# 이것은 첫 번째 문단이다.
#
# 이것은 두 번째 문단이다.

# %% [markdown]
# ### 줄바꿈
# * 문장 끝에 공백 2칸을 넣고 enter
# * 문장 끝에 \<br> 태그 넣기

# %% [markdown]
# 첫 줄입니다.
# 두 번째 줄입니다.

# %% [markdown]
# ## 강조
# * 굵게 \**
# * 기울임 \*
# * 굵고 기울임\***

# %% [markdown]
# **굵은 글씨**
# *기울임 글씨*
# ***굵고 기울임***

# %% [markdown]
# ## 목록

# %% [markdown]
# ### 순서 없는 목록 \-, \*

# %% [markdown]
# - 사과
#   - 부사
#   - 맛있는 사과
#     - 사과잼
# - 바나나
# - 포도

# %% [markdown]
# ### 순서 있는 목록

# %% [markdown]
# 1. 데이터 수집
# 2. 데이터 전처리
# 3. 모델 학습
# 4. 결과 분석

# %% [markdown]
# ## 중첩목록 \- \+ 들여쓰기

# %% [markdown]
# - 과일
#   - 사과
#   - 바나나
# - 채소
#   - 당근

# %% [markdown]
# ## 코드

# %% [markdown]
# ### 인라인 코드
# * 문장 중간에 코드를 표시할 때 백틱 1개 사용
# 변수는 `X=10` 처럼 정의한다.

# %% [markdown]
# ### 코드 블록
# * 여러 줄 코드를 표시할 때 백틱 3개를 사용
# * 언어 이름을 쓰면 문법 강조가 적용 됨

# %% [markdown]
# ``` python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# ## 인용문 \>

# %% [markdown]
# > 데이터 분석에서 가장 중요한 것은 질문이다.

# %% [markdown]
# ###  구분선 \---

# %% [markdown]
# ---

# %% [markdown]
# ## 링크
# * \[텍스트\](URL)

# %% [markdown]
# [구글 바로가기](https://www.google.com)

# %% [markdown]
# ## 이미지 넣기
# * \!\[이미지 예시\](https://cdn.dailyvet.co.kr/wp-content/uploads/2024/05/15231647/20240515ceva_experts4.jpg)

# %% [markdown]
# ![이미지 예시](https://cdn.dailyvet.co.kr/wp-content/uploads/2024/05/15231647/20240515ceva_experts4.jpg)

# %% [markdown]
# ![%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C.jpg](attachment:%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C.jpg)

# %% [markdown]
# ## 표 만들기
# ```
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |
# ```

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |:---|:---:|---:|
# | 철수님 | 20 | 컴퓨터공학 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# ## 체크박스
# ```
# 체크박스는 - [ ], 체크 완료는 - [x]이다.
# ```

# %% [markdown]
# - [ ] 데이터 수집
# - [X] 전처리
# - [ ] 모델 학습

# %% [markdown]
# ## 수식

# %% [markdown]
# ### 인라인 수식
# ```
# $y = ax + b$
# ```
# $y = ax + b$

# %% [markdown]
# ### 블록수식
# ```
# $$ \sum_{i=1}^{n} x_i $$
# ```
# $$ \sum_{i=1}^{n} x_i $$
